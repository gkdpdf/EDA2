# %% [markdown]
# ## 1

# %%
import pandas as pd

# %%
df = pd.read_excel('flight_price.xlsx')

# %%
df
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10681      Vistara      01/03/2019  Banglore   New Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %%
df.shape
# Out:
# (10683, 11)

# %% [markdown]
# ## 2

# %%
import seaborn as sns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int64
# dtypes: int64(1), object(10)
# memory usage: 918.2+ KB

# %%
sns.histplot(df['Price'],kde=True)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %% [markdown]
# ## 3

# %%
min_v = df['Price'].min()
max_v=df['Price'].max()

# %%
Range = max_v - min_v

# %%
Range
# Out:
# 77753

# %% [markdown]
# ## 4

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(25,6))
sns.histplot(data=df,x=df['Price'],kde=True,hue=df['Airline'],bins=50)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %%
plt.figure(figsize=(30,10))
sns.boxplot(data=df,y=df['Price'],x='Airline',hue='Airline')
# Out:
# <AxesSubplot: xlabel='Airline', ylabel='Price'>

# %% [markdown]
# ## 5

# %%
plt.figure(figsize=(30,10))
sns.boxplot(data=df,y=df['Price'],x='Airline',hue='Airline')
# Out:
# <AxesSubplot: xlabel='Airline', ylabel='Price'>

# %% [markdown]
# It will impact the distribution of the data and will impact the min_max range and also the standard deviation

# %% [markdown]
# ## 6

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
df['Month'] = df['Date_of_Journey'].str.split('/').str[1]

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price Month
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897    03
# 1    05:50         13:15   7h 25m     2 stops         No info   7662    05
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882    06
# 3    18:05         23:30   5h 25m      1 stop         No info   6218    05
# 4    16:50         21:35   4h 45m      1 stop         No info  13302    03

# %%
sns.histplot(data =df , x = 'Price',hue ='Month',bins=30)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %% [markdown]
# Peak Season ,month 6

# %% [markdown]
# ## 7

# %%
plt.subplots(2,2,figsize=(25,10))

plt.subplot(2,2,1)
sns.kdeplot(data=df,x='Price',fill=True,hue='Month')

plt.subplot(2,2,2)
# Create a countplot
ax = sns.countplot(x='Airline', data=df)

# Adjust the x-axis label font size
ax.set_xticklabels(ax.get_xticklabels(), fontsize=7)

plt.subplot(2,2,3)
sns.countplot(data=df ,x='Source')

plt.subplot(2,2,4)
sns.countplot(data=df ,x='Destination')
# Out:
# <AxesSubplot: xlabel='Destination', ylabel='count'>

# %% [markdown]
# ## 8

# %%
df['Month'] = df['Month'].astype(int)

# %%
df['Duration']= df['Duration'].str.split('h')

# %%
df.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time   Duration Total_Stops Additional_Info  Price  Month
# 0    22:20  01:10 22 Mar  [2,  50m]    non-stop         No info   3897      3
# 1    05:50         13:15  [7,  25m]     2 stops         No info   7662      5
# 2    09:25  04:25 10 Jun     [19, ]     2 stops         No info  13882      6
# 3    18:05         23:30  [5,  25m]      1 stop         No info   6218      5
# 4    16:50         21:35  [4,  45m]      1 stop         No info  13302      3

# %%
df['hour'] = df['Duration'].str[0]

# %%
df['min'] = df['Duration'].str[1]
df['min']= df['min'].str.split('m').str[0]

# %%
df['min'].unique()
# Out:
# array([' 50', ' 25', '', ' 45', ' 30', ' 5', ' 15', ' 35', ' 10', ' 20',
#        ' 55', ' 40', nan], dtype=object)

# %%
df['hour'].unique()
# Out:
# array([ 2,  7, 19,  5,  4, 15, 21, 25, 13, 12, 26, 22, 23, 20, 10,  6, 11,
#         8, 16,  3, 27,  1, 14,  9, 18, 17, 24, 30, 28, 29, 37, 34, 38, 35,
#        36, 47, 33, 32, 31, 42, 39, 41, 40])

# %%
df=df[df['hour']!='5m']
df=df[df['hour']!=' ']
df=df[df['min']!='']

# %%
df['hour'] =df['hour'].astype(int)
df['min'] =df['min'].astype(int)

# %%
df['Duration']=df['hour']*60+df['min']

# %%
df.head()
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 3     IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4     IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
# 5   SpiceJet      24/06/2019   Kolkata    Banglore              CCU → BLR
#
#   Dep_Time  Arrival_Time  Duration Total_Stops Additional_Info  Price  Month  \
# 0    22:20  01:10 22 Mar       170    non-stop         No info   3897      3
# 1    05:50         13:15       445     2 stops         No info   7662      5
# 3    18:05         23:30       325      1 stop         No info   6218      5
# 4    16:50         21:35       285      1 stop         No info  13302      3
# 5    09:00         11:25       145    non-stop         No info   3873      6
#
#    hour  min
# 0     2   50
# 1     7   25
# 3     5   25
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9651 entries, 0 to 10682
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          9651 non-null   object
#  1   Date_of_Journey  9651 non-null   object
#  2   Source           9651 non-null   object
#  3   Destination      9651 non-null   object
#  4   Route            9650 non-null   object
#  5   Dep_Time         9651 non-null   object
#  6   Arrival_Time     9651 non-null   object
#  7   Duration         9651 non-null   int64
#  8   Total_Stops      9650 non-null   object
#  9   Additional_Info  9651 non-null   object
#  10  Price            9651 non-null   int64
#  11  Month            9651 non-null   int64
#  12  hour             9651 non-null   int64
#  13  min              9651 non-null   int64
# dtypes: int64(5), object(9)
# memory usage: 1.1+ MB

# %%
sns.heatmap(df[['Price','Duration','Month']].corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# ## 9

# %%
df =pd.read_csv('googleplaystore.csv')

# %%
df.shape

# %% [markdown]
# ## 10

# %%
plt.figure(figsize=(25,10))
sns.kdeplot(data=df,x='Rating',hue='Category',palette='Paired')

# %%
plt.figure(figsize=(55,8))
sns.boxplot(data=df,y=df['Rating'],x=df['Category'])

# %% [markdown]
# ## 11

# %%
df.isnull().sum()

# %% [markdown]
# Yes it is present in the Rating, Type and Content Rating,Current ver and Android ver
# ###### Imputation need to be done for the missing values as it will impact the distribution

# %% [markdown]
# ## 12

# %%
df['Size'].unique()

# %%
df['Size']=df['Size'].str.replace('M','000')
df['Size']=df['Size'].str.replace('k',' ')

# %%
df['Size'].unique()

# %%
import numpy as np
df['Size']=df['Size'].replace('Varies with device',np.nan)
df['Size']=df['Size'].replace('1,000+',np.nan)
df['Size']=df['Size'].astype(float)

# %%
plt.figure(figsize=(25,10))
sns.scatterplot(data=df,x='Size',y='Rating')
plt.xlabel('Size in Kb')

# %% [markdown]
# ## 13

# %%
plt.figure(figsize=(25,10))
sns.kdeplot(data=df,x='Rating',hue='Category')

# %%
df['Price']=df['Price'].str.replace('$','')

# %%
df['Price']=df['Price'].replace('Everyone',np.nan)
df['Price']=df['Price'].replace('',np.nan)

# %%
df['Price'].unique()

# %%
df['Price']=df['Price'].astype(float)
df_price=df.groupby('Category').mean()
df_price

# %%
plt.figure(figsize=(50,20))
sns.barplot(data=df_price,y='Price',x='Category')

# %% [markdown]
# ## 14

# %%
df['Installs'].unique()
df['Installs']=df['Installs'].str.replace('+','')

# %%
df['Installs']=df['Installs'].replace(np.nan,'0')

# %%
df['Installs']=df['Installs'].astype(int)

# %%
df['Installs'].unique()

# %%
df['Installs'].value_counts().head(10)

# %% [markdown]
# ## 15

# %% [markdown]
# We will start with the :
# - Most number of category downloads
# - Best rated categories
# - Price is also high as comparison to other categories
# - Working on all android version

# %% [markdown]
# ## 16

# %%
df.head()

# %%
df_max=df.groupby('App').max()

# %%
a=df['Installs'].max()
b=df['Rating'].max()
c=df['Reviews'].max()

type(a)
df[df['Installs']==a].sort_values('Rating').tail(1)

# %% [markdown]
# ## 17

# %%
df.info()

# %%
df['Last Updated'].unique()

# %%
df['Last Updated'] = pd.to_datetime(df['Last Updated'])

## Not in the specific format
